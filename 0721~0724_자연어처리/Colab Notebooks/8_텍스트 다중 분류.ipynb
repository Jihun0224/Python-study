# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !apt-get update
# !apt-get install g++ openjdk-8-jdk
# !pip install JPype1
# !pip install rhinoMorph

# %%
naver_dir = '/content/gdrive/My Drive/pytest/네이버뉴스-생활문화_다중/'
import os
train_dir = os.path.join(naver_dir, 'train')
test_dir = os.path.join(naver_dir, 'test')
label_types = ['건강정보', '공연전시', '도로교통', '여행레저', '음식맛집', '자동차시승기', '종교', '책', '패션뷰티']

# %%
def make_texts_labels(dir, label_types, encode='utf8'): # texts와 labels 리스트를 만드는 함수
    texts = []
    labels = []
    for label_type in label_types:
        dir_name = os.path.join(dir, label_type) # 각각의 label 폴더에 접근한다
        for fname in os.listdir(dir_name):
            if fname[-4:] == '.txt': # 마지막 4 글자가 .txt 로 끝나는지를 확인한다
                f = open(os.path.join(dir_name, fname), encoding=encode)
                texts.append(f.read()) # 텍스트를 읽어서 texts 리스트에 연결한다
                f.close()
                if label_type == label_types[0]: # 만약 현재 폴더가 '건강정보' 폴더라면
                    labels.append(0) # texts와 같은 순서의 labels 리스트에는 0을 저장한다
                elif label_type == label_types[1]:
                    labels.append(1)
                elif label_type == label_types[2]:
                    labels.append(2)
                elif label_type == label_types[3]:
                    labels.append(3)
                elif label_type == label_types[4]:
                    labels.append(4)
                elif label_type == label_types[5]:
                    labels.append(5)
                elif label_type == label_types[6]:
                    labels.append(6)
                elif label_type == label_types[7]:
                    labels.append(7)
                elif label_type == label_types[8]:
                    labels.append(8)
        return texts, labels

# %%
# 훈련 데이터의 텍스트와 라벨을 받아온다
texts, labels = make_texts_labels(train_dir, label_types)
print('texts 0:', texts[0])
print('texts len:', len(texts))
print('labels 0:', labels[0])
print('labels len:', len(labels))
# Out:
# texts 0: 평창올림픽 복병 '노로바이러스'…감염자 접촉 '조심' : 네이버 뉴스
#
#
#
#
#
#
#
# 노로바이러스 등 감염병 예방을 위해 올림픽 경기장 출입문 앞에서 보안업무 중인 군인들 © News1 임세영 기자음식은 반드시 익혀먹어야…예방은 손씻기부터(서울=뉴스1) 음상준 기자 = '노로바이러스'가 평창올림픽 복병으로 떠올랐다. '2018 평창 동계올림픽'이 열리는 평창과 강릉 지역에 노로바이러스 감염자가 급증하고 있어, 보건당국이 긴장하고 있다.12일 평창올림픽 조직위원회에 따르면 11일 오후 4시를 기준으로 노로바이러스 확진자가 177명으로 집계됐다. 노로바이러스 확진자는 지난 7일 86명으로 최고치를 기록한 뒤 9일 11명으로 줄었다가 10일과 11일 19명으로 확진자가 늘었다. 올림픽 경기를 보기 위해 전세계에서 수십만명이 이 지역에 체류하고 있어, 확진자는 계속 늘어날 가능성이 높다.김진수 서울성모병원 소화기내과 교수는 "노로바이러스는 오염된 음식물뿐 아니라 사람간 접촉으로도 전염된다"며 "어린이와 노인들은 후유증을 우려해 신속한 입원치료를 받아야 한다"고 설명했다.질병관리본부와 서울대병원에 따르면 노로바이러스는 영하 20도 이하 낮은 온도에도 살아남는 대표적인 겨울철 식중독균이다. 주로 오염된 지하수와 채소, 과일, 해조류 등을 먹거나 감염자를 만지면 감염된다. 감염자가 손을 씻지 않고 만진 문고리를 만져도 병에 걸릴 정도로 전염성이 강하다.노로바이러스에 걸리면 24~48시간의 잠복기를 거쳐 구토와 설사, 탈수, 복통, 근육통, 두통, 열증상 같은 후유증을 48~72시간동안 겪는다. 어린이는 구토, 성인은 설사가 흔한 증상이다. 감염자 2명 중 1명꼴로 고열에 시달린다. 전염성이 강한 만큼 단체생활을 하는 학교나 군대, 요양원에서 환자가 많이 발생한다. 이 감염병을 예방하려면 외출 후 집에 돌아와 반드시 손을 씻어야 한다. 노로바이러스는 입자가 27~40나노미터(nm·10억분의 1m)로 매우 작아 30초 이상 비누나 세정제를 이용해 손가락과 손등까지 구석구석 닦는다. 음식물은 되도록 익혀먹어야 안전하다. 굴 등 어패류는 섭씨 85도에서 1분 이상 익히고, 지하수는 반드시 끓여 마셔야 한다. 채소나 과일류는 깨끗한 물로 씻은 뒤 먹는다. 집안 화장실 변기, 문 손잡이 등은 가정용 염소소독제를 40배로 희석해 청소하는 방식을 추천한다. 1000밀리리터(㎖) 염소소독제를 40배 희석하는 방법은 물 975㎖에 염소소독제 25㎖를 섞으면 된다. 지하수는 정기적으로 수질 검사를 진행해 오염 정도를 파악하고 공용시설 물탱크는 6개월에 1회 이상 청소한다. 김진수 교수는 "노로바이러스에 걸린 노약자는 수액을 공급해 탈수증을 예방하고 증상에 따라 항생제나 진정제를 처방한다"며 "손씻기부터 식습관까지 개인위생을 철저히 지키는 게 가장 효과적인 예방법"이라고 강조했다.sj@▶ '평창2018' 관련 뉴스·포토 보기▶ 네이버메인에 ‘뉴스1채널’ 설정하기!▶ 여러분의 제보를 기다립니다.제보하기![© 뉴스1코리아(news1.kr), 무단 전재 및 재배포 금지]
#
#
# texts len: 10
# labels 0: 0
# labels len: 10

# %%
# 한글은 tokenizing을 위해서 먼저 형태소분석을 해야 한다
import rhinoMorph
rn = rhinoMorph.startRhino() 
# 리스트 컴프리헨션으로 실질형태소만을 리스트로 가져온다
texts = [rhinoMorph.onlyMorph_list(rn, sentence, pos=['NNG', 'NNP', 'NP', 'VV', 'VA', 'XR', 
'IC', 'MM', 'MAG', 'MAJ'], eomi=False) for sentence in texts]
print(texts[0])
# Out:
# filepath:  /usr/local/lib/python3.7/dist-packages
# classpath:  /usr/local/lib/python3.7/dist-packages/rhinoMorph/lib/rhino.jar
# RHINO started!
# ['평창', '올림픽', '복병', '노', '로', '바이러스', '감염자', '접촉', '조심', '네이버', '뉴스', '노', '로', '바이러스', '감염', '병', '예방', '위하', '올림픽', '경기장', '출입문', '앞', '보안', '업무', '군인', '임세영', '기자', '음식', '반드시', '익히', '예방', '손', '씻기', '서울', '뉴스', '음상', '줄', '기자', '노', '로', '바이러스', '평창', '올림픽', '복병', '떠오르', '평창', '동계', '올림픽', '열리', '평창', '강릉', '지역', '노', '로', '바이러스', '감염자', '급증', '있', '보건', '당국', '긴장', '있', '평창', '올림픽', '조직', '위원회', '따르', '오후', '기준', '노', '로', '바이러스', '확진자', '집계', '되', '노', '로', '바이러스', '확진자', '지나', '최고', '기록', '하', '뒤', '주', '일', '확진자', '늘', '올림픽', '경기', '보', '위하', '전', '세계', '명', '이', '지역', '체류', '있', '확진자', '계속', '늘어나', '가능성', '높', '김진수', '서울성모병원', '소화기', '내과', '교수', '노', '로', '바이러스', '오염', '되', '음식물', '사람', '접촉', '전염', '되', '어린이', '노인', '후유증', '우려', '신속', '하', '입원', '치료', '받', '설명', '질병', '관리', '본부', '서울대병원', '따르', '노', '로', '바이러스', '영하', '이하', '낮', '온도', '살아남', '대표적', '겨울철', '식중독', '균', '주로', '오염', '되', '지하수', '채소', '과일', '해조', '등', '감염자', '만지', '감염', '되', '감염자', '손', '씻', '만지', '문고리', '만지', '병', '걸리', '정도', '전염', '강하', '노', '로', '바이러스', '걸리', '시간', '잠복기', '거치', '구토', '설사', '탈수', '복통', '근육통', '두통', '열', '증상', '같', '후유증', '동안', '겪', '어린이', '구토', '성인', '설사', '흔하', '증상', '감염자', '열', '시달리', '전염', '강하', '단체', '생활', '하', '학교', '군대', '요양원', '환자', '많이', '발생', '이', '감염', '병', '예방', '외출', '후', '집', '돌아오', '반드시', '손', '씻', '노', '로', '바이러스', '입자', '매우', '작', '이상', '비누', '세정제', '이용', '손가락', '손등', '구석구', '닦', '음식물', '되도록', '익히', '안전', '굴', '어패', '섭씨', '이상', '익히', '지하수', '반드시', '끓이', '마시', '채소', '과일', '깨끗', '물', '씻', '뒤', '먹', '집안', '화장실', '변기', '문', '손잡이', '가정', '염소', '소독제', '배', '희석', '청소', '방식', '추천', '밀리리터', '염소', '소독제', '배', '희석', '방법', '물', '염소', '소독제', '섞', '되', '지하수', '정기적', '수질', '검사', '진행', '오염', '정도', '파악', '공용', '시설', '물탱크', '이상', '청소', '김진수', '교수', '노', '로', '바이러스', '걸리', '노약자', '수액', '공급', '탈수증', '예방', '증상', '따르', '항생제', '진정제', '처방', '하', '손', '씻기', '식습관', '개인', '위생', '철저히', '지키', '가장', '효과적', '예방법', '강조', '평창', '관련', '뉴스', '포토', '네이버', '메인', '뉴스', '채널', '설정', '여러분', '제보', '기다리', '제보', '뉴스', '코리아', '무단', '전재', '및', '배포', '금지']

# %%
# %tensorflow_version 2.x
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np
import math

validation_ratio = math.floor(len(texts) * 0.3) # 30%는 검증데이터로 사용한다. 나머지는 훈련데이터
max_words = 10000 # 데이터셋에서 가장 빈도 높은 10,000 개의 단어만 사용한다
maxlen = 200 # 200개 이후의 단어는 버린다
class_number = 9 # 분류할 클래스의 수

tokenizer = Tokenizer(num_words=max_words) # 상위빈도 10,000 개의 단어만을 추려내는 Tokenizer 객체 생성
tokenizer.fit_on_texts(texts) # 단어 인덱스를 구축한다
word_index = tokenizer.word_index # 단어 인덱스만 가져온다
